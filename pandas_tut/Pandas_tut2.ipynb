# %%
import pandas as pd 
import numpy as np

# %%
#Complete raw data
df=pd.read_csv("world_alcohol.csv",nrows=20,keep_default_na=False)
df
# Out:
#     Year       WHO region                Country Beverage Types Display Value
# 0   1986  Western Pacific               Viet Nam           Wine             0
# 1   1986             null                Uruguay          Other           0.5
# 2   1985           Africa           Cte d'Ivoire           Wine          1.62
# 3   1986         Americas                   #N/A           Beer          4.27
# 4   1987         Americas  Saint Kitts and Nevis      not given          1.98
# 5   1987                ?              Guatemala          Other             0
# 6   1987              NaN              Mauritius           Wine          0.13
# 7    NaN              NaN                    NaN            NaN           NaN
# 8    NaN         Americas                    NaN        Spirits          1.55
# 9   1984           Africa                Nigeria          Other
# 10  1987           Africa               Botswana              ?           0.2
# ...

# %%
df.set_index("WHO region", inplace=True)

# %%
print(df.loc['Africa'])
# Out:
#                  Year       Country Beverage Types  Display Value
# WHO region
# Africa     1985-01-01  Cte d'Ivoire           Wine           1.62
# Africa     1984-01-01       Nigeria          Other            NaN

# %%
df=pd.read_csv("world_alcohol.csv",nrows=6,parse_dates=['Year'])
df
# Out:
#         Year       WHO region                Country Beverage Types  \
# 0 1986-01-01  Western Pacific               Viet Nam           Wine
# 1 1986-01-01              NaN                Uruguay          Other
# 2 1985-01-01           Africa           Cte d'Ivoire           Wine
# 3 1986-01-01         Americas                    NaN           Beer
# 4 1987-01-01         Americas  Saint Kitts and Nevis      not given
# 5 1987-01-01                ?              Guatemala          Other
#
#    Display Value
# 0           0.00
# 1           0.50
# 2           1.62
# 3           4.27
# 4           1.98
# 5           0.00

# %%
df=pd.read_csv("world_alcohol.csv",nrows=7,na_values=['?','not given','no values','Other'],parse_dates=['Year'])
df
# Out:
#         Year       WHO region                Country Beverage Types  \
# 0 1986-01-01  Western Pacific               Viet Nam           Wine
# 1 1986-01-01              NaN                Uruguay            NaN
# 2 1985-01-01           Africa           Cte d'Ivoire           Wine
# 3 1986-01-01         Americas                    NaN           Beer
# 4 1987-01-01         Americas  Saint Kitts and Nevis            NaN
# 5 1987-01-01              NaN              Guatemala            NaN
# 6 1987-01-01              NaN              Mauritius           Wine
#
#    Display Value
# 0           0.00
# 1           0.50
# 2           1.62
# 3           4.27
# 4           1.98
# 5           0.00
# 6           0.13

# %%
# df.interpolate(method='time')

# %%
#handling missing data
#0=rowa
#1=cols
# df.dropna(axis=0)

# %%
df.set_index("Year", inplace=True)

# %%
df2=df[df.isna().any(axis=1)]
print(df2)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#
# KeyError: 1
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-89c87de01000> in <module>
# ----> 1 df2=df[df.isna().any(axis=1)]
#       2 print(df2)
#
# ~\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\generic.py in any(self, axis, bool_only, skipna, level, **kwargs)
#   10867         )
#   10868         def any(self, axis=0, bool_only=None, skipna=True, level=None, **kwargs):
# ...

# %%
df.dropna(subset=['Year'],inplace=True)
df
# Out:
#          Year       WHO region                Country Beverage Types  \
# 0  1986-01-01  Western Pacific               Viet Nam           Wine
# 1  1986-01-01              NaN                Uruguay            NaN
# 2  1985-01-01           Africa           Cte d'Ivoire           Wine
# 3  1986-01-01         Americas                    NaN           Beer
# 4  1987-01-01         Americas  Saint Kitts and Nevis            NaN
# 5  1987-01-01              NaN              Guatemala            NaN
# 6  1987-01-01              NaN              Mauritius           Wine
# 9  1984-01-01           Africa                Nigeria            NaN
# 10 1987-01-01           Africa               Botswana            NaN
# 11 1989-01-01         Americas              Guatemala           Beer
# 12 1985-01-01              NaN                    NaN           Beer
# 13 1984-01-01              NaN            Afghanistan            NaN
# 14 1985-01-01  Western Pacific                    NaN        Spirits
# ...

# %%
df01=df

# %%
df.interpolate(method='polynomial',order=1)
# Out:
#          Year       WHO region                Country Beverage Types  \
# 0  1986-01-01  Western Pacific               Viet Nam           Wine
# 1  1986-01-01              NaN                Uruguay            NaN
# 2  1985-01-01           Africa           Cte d'Ivoire           Wine
# 3  1986-01-01         Americas                    NaN           Beer
# 4  1987-01-01         Americas  Saint Kitts and Nevis            NaN
# 5  1987-01-01              NaN              Guatemala            NaN
# 6  1987-01-01              NaN              Mauritius           Wine
# 9  1984-01-01           Africa                Nigeria            NaN
# 10 1987-01-01           Africa               Botswana            NaN
# 11 1989-01-01         Americas              Guatemala           Beer
# 12 1985-01-01              NaN                    NaN           Beer
# 13 1984-01-01              NaN            Afghanistan            NaN
# 14 1985-01-01  Western Pacific                    NaN        Spirits
# ...

# %%
df.dropna(thresh=4,inplace=True)
df
# Out:
#          Year       WHO region                Country Beverage Types  \
# 0  1986-01-01  Western Pacific               Viet Nam           Wine
# 2  1985-01-01           Africa           Cte d'Ivoire           Wine
# 3  1986-01-01         Americas                    NaN           Beer
# 4  1987-01-01         Americas  Saint Kitts and Nevis            NaN
# 6  1987-01-01              NaN              Mauritius           Wine
# 10 1987-01-01           Africa               Botswana            NaN
# 11 1989-01-01         Americas              Guatemala           Beer
# 14 1985-01-01  Western Pacific                    NaN        Spirits
# 15 1987-01-01           Africa          Guinea-Bissau           Wine
# 16 1984-01-01              NaN             Costa Rica           Wine
# 17 1989-01-01           Africa             Seychelles           Beer
# 18 1984-01-01           Europe                 Norway        Spirits
# 19 1984-01-01           Africa                  Kenya           Beer
#
# ...

# %%
df.dropna(subset=['WHO region','Beverage Types'])
# Out:
#          Year       WHO region        Country Beverage Types  Display Value
# 0  1986-01-01  Western Pacific       Viet Nam           Wine           0.00
# 2  1985-01-01           Africa   Cte d'Ivoire           Wine           1.62
# 3  1986-01-01         Americas            NaN           Beer           4.27
# 11 1989-01-01         Americas      Guatemala           Beer           0.62
# 14 1985-01-01  Western Pacific            NaN        Spirits           0.05
# 15 1987-01-01           Africa  Guinea-Bissau           Wine           0.07
# 17 1989-01-01           Africa     Seychelles           Beer           2.23
# 18 1984-01-01           Europe         Norway        Spirits           1.62
# 19 1984-01-01           Africa          Kenya           Beer           1.08

# %%
df
# Out:
#          Year       WHO region                Country Beverage Types  \
# 0  1986-01-01  Western Pacific               Viet Nam           Wine
# 2  1985-01-01           Africa           Cte d'Ivoire           Wine
# 3  1986-01-01         Americas                    NaN           Beer
# 4  1987-01-01         Americas  Saint Kitts and Nevis            NaN
# 6  1987-01-01              NaN              Mauritius           Wine
# 10 1987-01-01           Africa               Botswana            NaN
# 11 1989-01-01         Americas              Guatemala           Beer
# 14 1985-01-01  Western Pacific                    NaN        Spirits
# 15 1987-01-01           Africa          Guinea-Bissau           Wine
# 16 1984-01-01              NaN             Costa Rica           Wine
# 17 1989-01-01           Africa             Seychelles           Beer
# 18 1984-01-01           Europe                 Norway        Spirits
# 19 1984-01-01           Africa                  Kenya           Beer
#
# ...

# %%
df.fillna(0)
# Out:
#          Year       WHO region                Country Beverage Types  \
# 0  1986-01-01  Western Pacific               Viet Nam           Wine
# 2  1985-01-01           Africa           Cte d'Ivoire           Wine
# 3  1986-01-01         Americas                      0           Beer
# 4  1987-01-01         Americas  Saint Kitts and Nevis              0
# 6  1987-01-01                0              Mauritius           Wine
# 10 1987-01-01           Africa               Botswana              0
# 11 1989-01-01         Americas              Guatemala           Beer
# 14 1985-01-01  Western Pacific                      0        Spirits
# 15 1987-01-01           Africa          Guinea-Bissau           Wine
# 16 1984-01-01                0             Costa Rica           Wine
# 17 1989-01-01           Africa             Seychelles           Beer
# 18 1984-01-01           Europe                 Norway        Spirits
# 19 1984-01-01           Africa                  Kenya           Beer
#
# ...

# %%
df.fillna({'Beverage Types':'Other'},inplace=True)
df
# Out:
#          Year       WHO region                Country Beverage Types  \
# 0  1986-01-01  Western Pacific               Viet Nam           Wine
# 2  1985-01-01           Africa           Cte d'Ivoire           Wine
# 3  1986-01-01         Americas                    NaN           Beer
# 4  1987-01-01         Americas  Saint Kitts and Nevis          Other
# 6  1987-01-01              NaN              Mauritius           Wine
# 10 1987-01-01           Africa               Botswana          Other
# 11 1989-01-01         Americas              Guatemala           Beer
# 14 1985-01-01  Western Pacific                    NaN        Spirits
# 15 1987-01-01           Africa          Guinea-Bissau           Wine
# 16 1984-01-01              NaN             Costa Rica           Wine
# 17 1989-01-01           Africa             Seychelles           Beer
# 18 1984-01-01           Europe                 Norway        Spirits
# 19 1984-01-01           Africa                  Kenya           Beer
#
# ...

# %%
df = df.bfill(axis=1)
df
# Out:
#          Year       WHO region                Country Beverage Types  \
# 0  1986-01-01  Western Pacific               Viet Nam           Wine
# 2  1985-01-01           Africa           Cte d'Ivoire           Wine
# 3  1986-01-01         Americas                   Beer           Beer
# 4  1987-01-01         Americas  Saint Kitts and Nevis          Other
# 6  1987-01-01        Mauritius              Mauritius           Wine
# 10 1987-01-01           Africa               Botswana          Other
# 11 1989-01-01         Americas              Guatemala           Beer
# 14 1985-01-01  Western Pacific                Spirits        Spirits
# 15 1987-01-01           Africa          Guinea-Bissau           Wine
# 16 1984-01-01       Costa Rica             Costa Rica           Wine
# 17 1989-01-01           Africa             Seychelles           Beer
# 18 1984-01-01           Europe                 Norway        Spirits
# 19 1984-01-01           Africa                  Kenya           Beer
#
# ...

# %%
df.replace({'WHO region':['Mauritius']},'Americas',inplace=True)
df
# Out:
#          Year       WHO region                Country Beverage Types  \
# 0  1986-01-01  Western Pacific               Viet Nam           Wine
# 2  1985-01-01           Africa           Cte d'Ivoire           Wine
# 3  1986-01-01         Americas                   Beer           Beer
# 4  1987-01-01         Americas  Saint Kitts and Nevis          Other
# 6  1987-01-01         Americas              Mauritius           Wine
# 10 1987-01-01           Africa               Botswana          Other
# 11 1989-01-01         Americas              Guatemala           Beer
# 14 1985-01-01  Western Pacific                Spirits        Spirits
# 15 1987-01-01           Africa          Guinea-Bissau           Wine
# 16 1984-01-01       Costa Rica             Costa Rica           Wine
# 17 1989-01-01           Africa             Seychelles           Beer
# 18 1984-01-01           Europe                 Norway        Spirits
# 19 1984-01-01           Africa                  Kenya           Beer
#
# ...

# %%
df.replace({'WHO region':['Costa Rica']},'Western Pacific',inplace=True)
df
# Out:
#          Year       WHO region                Country Beverage Types  \
# 0  1986-01-01  Western Pacific               Viet Nam           Wine
# 2  1985-01-01           Africa           Cte d'Ivoire           Wine
# 3  1986-01-01         Americas                   Beer           Beer
# 4  1987-01-01         Americas  Saint Kitts and Nevis          Other
# 6  1987-01-01         Americas              Mauritius           Wine
# 10 1987-01-01           Africa               Botswana          Other
# 11 1989-01-01         Americas              Guatemala           Beer
# 14 1985-01-01  Western Pacific                Spirits        Spirits
# 15 1987-01-01           Africa          Guinea-Bissau           Wine
# 16 1984-01-01  Western Pacific             Costa Rica           Wine
# 17 1989-01-01           Africa             Seychelles           Beer
# 18 1984-01-01           Europe                 Norway        Spirits
# 19 1984-01-01           Africa                  Kenya           Beer
#
# ...

# %%
df.replace({'Country':['Beer','Spirits']},'Country not given',inplace=True)
df
# Out:
#          Year       WHO region                Country Beverage Types  \
# 0  1986-01-01  Western Pacific               Viet Nam           Wine
# 2  1985-01-01           Africa           Cte d'Ivoire           Wine
# 3  1986-01-01         Americas      Country not given           Beer
# 4  1987-01-01         Americas  Saint Kitts and Nevis          Other
# 6  1987-01-01         Americas              Mauritius           Wine
# 10 1987-01-01           Africa               Botswana          Other
# 11 1989-01-01         Americas              Guatemala           Beer
# 14 1985-01-01  Western Pacific      Country not given        Spirits
# 15 1987-01-01           Africa          Guinea-Bissau           Wine
# 16 1984-01-01  Western Pacific             Costa Rica           Wine
# 17 1989-01-01           Africa             Seychelles           Beer
# 18 1984-01-01           Europe                 Norway        Spirits
# 19 1984-01-01           Africa                  Kenya           Beer
#
# ...

# %%
df.replace('Country not given',method='bfill')
# Out:
# C:\Users\naush\AppData\Local\Programs\Python\Python39\lib\site-packages\pandas\core\missing.py:56: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= arr == x
#          Year       WHO region                Country Beverage Types  \
# 0  1986-01-01  Western Pacific               Viet Nam           Wine
# 2  1985-01-01           Africa           Cte d'Ivoire           Wine
# 3  1986-01-01         Americas  Saint Kitts and Nevis           Beer
# 4  1987-01-01         Americas  Saint Kitts and Nevis          Other
# 6  1987-01-01         Americas              Mauritius           Wine
# 10 1987-01-01           Africa               Botswana          Other
# 11 1989-01-01         Americas              Guatemala           Beer
# 14 1985-01-01  Western Pacific          Guinea-Bissau        Spirits
# 15 1987-01-01           Africa          Guinea-Bissau           Wine
# ...

# %%
type(df.Year[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
'''
what is data
In computing, data is information that has been translated into a form that is efficient for movement or processing. 
We use data science to make it easier to work with data. 
data is different types of information usually formatted in a particular manner.

data preprocessing is a process to convert raw data into meaningful data using different techniques.

Data in real world is dirty ie
-incomplete 
-noisy
-inconsistent
-duplicate

Quality elements of data 

-accuracy
-completeness
-consistency
-believability
-interpretability

Machine learning algorithm follow the rule gigo
thats why quality data is important

Major steps in data preprocessing

data cleaning
data interagation
 ""  reduction
 ""  tranformation
 ""  discretization

'''
# Out:
# '\nwhat is data\nIn computing, data is information that has been translated into a form that is efficient for movement or processing. \nWe use data science to make it easier to work with data. \ndata is different types of information usually formatted in a particular manner.\n\ndata preprocessing is a process to convert raw data into meaningful data using different techniques.\n\nData in real world is dirty ie\n-incomplete \n-noisy\n-inconsistent\n-duplicate\n\nQuality elements of data \n\n-accuracy\n-completeness\n-consistency\n-believability\n-interpretability\n\nMachine learning algorithm follow the rule gigo\nthats why quality data is important\n\nMajor steps in data preprocessing\n\ndata cleaning\ndata interagation\n ""  reduction\n ""  tranformation\n ""  discretization\n\n'

# %%
#interpolate :- method axis limit inplace limit_direction limit_area
#datatypes should be same for axis=0

# %%
df.dtypes
# Out:
# Year              datetime64[ns]
# WHO region                object
# Country                   object
# Beverage Types            object
# Display Value             object
# dtype: object
